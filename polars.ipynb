# %% [markdown]
# **https://www.cienciadedatos.net/documentos/pyml01-intro_polars_es.html
#
# https://pola-rs.github.io/polars-book/user-guide/introduction.html
#
# https://pola-rs.github.io/polars/py-polars/html/reference/
# **

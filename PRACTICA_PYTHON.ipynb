# %% [markdown]
# ##**Puzzles de Programación en Python**

# %% [markdown]
# ###Escribe un programa en Python para encontrar una lista de enteros con exactamente dos apariciones de diecinueve y al menos tres apariciones de cinco. Devolver True en caso contrario False

# %%
numeros = [19,3,5,6,7,1,0,3,100,19,5,5,5]
# comparar = 19
# contador
# salida = False
comparar_19, comparar_5, contador_19, contador_5, salida = 19 ,5 , 0 ,0 , False

for i in numeros:
  if (i == comparar_19):
    contador_19 += 1
  if(i == comparar_5):
    contador_5 += 1
  
if(contador_19 > 1 and contador_5 > 3):
   salida = True
else:
   salida

print(salida)
# Out:
# True

# %%
def testear(numeros):
    return numeros.count(19) == 2 and numeros.count(5) >= 3

numeros = [19,19,15,5,3,5,5,2]
print("Lista Original:")
print(numeros)
print("Compruebe dos apariciones de diecinueve y al menos tres apariciones de cinco en dicha lista:")
print(testear(numeros))
numeros = [19,15,15,5,3,3,5,2]
print("\nLista Original:")
print(numeros)
print("Compruebe dos apariciones de diecinueve y al menos tres apariciones de cinco en dicha lista:")
print(testear(numeros))
numeros = [19,19,5,5,5,5,5]
print("\nLista Original:")
print(numeros)
print("Compruebe dos apariciones de diecinueve y al menos tres apariciones de cinco en dicha lista:")
print(testear(numeros))
# Out:
# Lista Original:
# [19, 19, 15, 5, 3, 5, 5, 2]
# Compruebe dos apariciones de diecinueve y al menos tres apariciones de cinco en dicha lista:
# True
#
# Lista Original:
# [19, 15, 15, 5, 3, 3, 5, 2]
# Compruebe dos apariciones de diecinueve y al menos tres apariciones de cinco en dicha lista:
# False
#
# Lista Original:
# [19, 19, 5, 5, 5, 5, 5]
# Compruebe dos apariciones de diecinueve y al menos tres apariciones de cinco en dicha lista:
# True

# %% [markdown]
# ###**Escribe un programa en Python que acepte una lista de enteros y calcule la longitud y el quinto elemento. Devuelve verdadero si la longitud de la lista es 8 y el quinto elemento aparece tres veces en dicha lista.**

# %%
def listaEnteros(numeros):

  cantidad = len(numeros)
  
  contador_pos_5, elemento, num_capturado, salida = 0, 4, 0, False

  for index, numero in enumerate(numeros):
    if(index == 4):
      num_capturado = numero
 
  for index, numero in enumerate(numeros):
    if(numero == num_capturado):
      contador_pos_5 += 1
  
  if(cantidad == 8 and contador_pos_5 == 3):
    salida = True
  else:
    salida

  return salida
    #print(index, numero)

print(listaEnteros([19, 19, 15, 5, 5, 5, 1, 2]))
print(listaEnteros([19, 15, 5, 7, 5, 5, 2]))
print(listaEnteros([11, 12, 14, 13, 14, 13, 15, 14]))
print(listaEnteros([19, 15, 11, 7, 5, 6, 2]))
# Out:
# True
# False
# True
# False

# %%
def test(nums):
    return len(nums) == 8 and nums.count(nums[4]) == 3

def imprimir(nums):
  print("Lista original:")
  print(nums)
  print("Compruebe si la longitud de dicha lista es 8 y el quinto elemento aparece tres veces en dicha lista. :")
  print(test(nums))

imprimir([19,19,15,5,5,5,1,2])
imprimir([19,15,5,7,5,5,2])
imprimir([11,12,14,13,14,13,15,14])
imprimir([19,15,11,7,5,6,2])

# nums = [19,19,15,5,5,5,1,2]
# print("Lista original:")
# print(nums)
# print("Compruebe si la longitud de dicha lista es 8 y el quinto elemento aparece tres veces en dicha lista. :")
# print(test(nums))
# nums = [19,15,5,7,5,5,2]
# print("\nLista original")
# print(nums)
# print("Compruebe si la longitud de dicha lista es 8 y el quinto elemento aparece tres veces en dicha lista. :")
# print(test(nums))
# nums = [11,12,14,13,14,13,15,14]
# print("\nLista original")
# print(nums)
# print("Compruebe si la longitud de dicha lista es 8 y el quinto elemento aparece tres veces en dicha lista. :")
# print(test(nums))
# nums = [19,15,11,7,5,6,2]
# print("\nLista original")
# print(nums)
# print("Compruebe si la longitud de dicha lista es 8 y el quinto elemento aparece tres veces en dicha lista. :")
# print(test(nums))
# Out:
# Lista original:
# [19, 19, 15, 5, 5, 5, 1, 2]
# Compruebe si la longitud de dicha lista es 8 y el quinto elemento aparece tres veces en dicha lista. :
# True
# Lista original:
# [19, 15, 5, 7, 5, 5, 2]
# Compruebe si la longitud de dicha lista es 8 y el quinto elemento aparece tres veces en dicha lista. :
# False
# Lista original:
# [11, 12, 14, 13, 14, 13, 15, 14]
# Compruebe si la longitud de dicha lista es 8 y el quinto elemento aparece tres veces en dicha lista. :
# True
# Lista original:
# [19, 15, 11, 7, 5, 6, 2]
# Compruebe si la longitud de dicha lista es 8 y el quinto elemento aparece tres veces en dicha lista. :
# False

# %% [markdown]
# ###**Escribe un programa en Python que acepte un entero y determine si es mayor que 4^4 y que es 4 mod 34.**

# %%
def test(n):
    return n % 34 == 4 and n > 4 ** 4

def imprimir(n):
  print("Entero original:")
  print(n)
  print("Comprueba si dicho entero es mayor que 4^4 y que es 7 mod 134 :")
  print(test(n))

imprimir(922)
imprimir(914)
imprimir(854)
imprimir(999)
# n = 922
# print("Entero original:")
# print(n)
# print("Comprueba si dicho entero es mayor que 4^4 y que es 7 mod 134 :")
# print(test(n))
# n = 914
# print("\nOriginal Integer:")
# print(n)
# print("Check whether the said integer greater than 4^4 and which is 7 mod 134 :")
# print(test(n))
# n = 854
# print("\nOriginal Integer:")
# print(n)
# print("Check whether the said integer greater than 4^4 and which is 7 mod 134 :")
# print(test(n))
# print("\nOriginal Integer:")
# print(n)
# print("Check whether the said integer greater than 4^4 and which is 7 mod 134 :")
# print(test(n))
# Out:
# Entero original:
# 922
# Comprueba si dicho entero es mayor que 4^4 y que es 7 mod 134 :
# True
# Entero original:
# 914
# Comprueba si dicho entero es mayor que 4^4 y que es 7 mod 134 :
# False
# Entero original:
# 854
# Comprueba si dicho entero es mayor que 4^4 y que es 7 mod 134 :
# True
# Entero original:
# 999
# Comprueba si dicho entero es mayor que 4^4 y que es 7 mod 134 :
# False

# %%
archivo = open('/content/drive/MyDrive/Colab Notebooks/ESTUDIO HENRY/Emisiones_CO2.csv','r')#, encoding = 'ANSI')

# %%
import os
archivo = open('/content/drive/MyDrive/Colab Notebooks/ESTUDIO HENRY/Emisiones_CO2.csv', 'r')#, encoding = 'ANSI')

# %%
archivo
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/Colab Notebooks/ESTUDIO HENRY/Emisiones_CO2 .csv' mode='r' encoding='UTF-8'>

# %%
print(archivo)
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/Colab Notebooks/ESTUDIO HENRY/Emisiones_CO2 .csv' mode='r' encoding='UTF-8'>

# %%
dicc_emisiones = {  'cod_pais' : [],
                    'nom_pais' : [],
                    'region' : [],
                    'anio' : [],
                    'co2' : [],
                    'co2_percapita' : []}

# %%
next(archivo)
for linea in archivo:
    linea = linea.strip()
    campos = linea.split('|')
    print(campos)
    break
    # dicc_emisiones['cod_pais'].append(campos[0])
    # dicc_emisiones['nom_pais'].append(campos[1])
    # dicc_emisiones['region'].append(campos[2])
    # dicc_emisiones['anio'].append(campos[3])
    # dicc_emisiones['co2'].append(campos[4])
    # dicc_emisiones['co2_percapita'].append(campos[5])
